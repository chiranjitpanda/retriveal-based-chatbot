# %%
import bs4 as bs  ## to scrap the web pages
import urllib.request  ##  for fetching the target url's

# %%
df = urllib.request.urlopen('https://en.wikipedia.org/wiki/Chatbot').read()

# %%
df
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Chatbot - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"dc228cf9-3135-4cbe-a75a-caa96dac41d0","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Chatbot","wgTitle":"Chatbot","wgCurRevisionId":1075136095,"wgRevisionId":1075136095,"wgArticleId":148349,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 errors: missing periodical","Articles with short description","Short description is different from Wikidata","Pages using div col with small parameter","Articl
# ...

# %%
df_paragraph = bs.BeautifulSoup(df,'html').find_all('p')

# %%
df_paragraph
# Out:
# [<p>A <b>chatbot</b> or <b>chatterbot</b> is a <a href="/wiki/Software_agent" title="Software agent">software</a> application used to conduct an on-line chat <a href="/wiki/Conversation" title="Conversation">conversation</a> via text or <a href="/wiki/Speech_synthesis" title="Speech synthesis">text-to-speech</a>, in lieu of providing direct contact with a live human agent.<sup class="reference" id="cite_ref-target_1-0"><a href="#cite_note-target-1">[1]</a></sup><sup class="reference" id="cite_ref-:1_2-0"><a href="#cite_note-:1-2">[2]</a></sup>A chatbot is a type of software that can help customersby automating conversations and interact with them through messaging platforms.<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup> Designed to convincingly simulate the way a human would behave as a conversational partner, chatbot systems typically require continuous tuning and testing, and many in production remain unable to adequately converse, while none of them ca
# ...

# %%
## creating the corpus
corpus=''

# %%
for p in df_paragraph:
    corpus = corpus+p.text.lower()
print(corpus)
# Out:
# a chatbot or chatterbot is a software application used to conduct an on-line chat conversation via text or text-to-speech, in lieu of providing direct contact with a live human agent.[1][2]a chatbot is a type of software that can help customersby automating conversations and interact with them through messaging platforms.[3] designed to convincingly simulate the way a human would behave as a conversational partner, chatbot systems typically require continuous tuning and testing, and many in production remain unable to adequately converse, while none of them can pass the standard turing test.[4] the term "chatterbot" was originally coined by michael mauldin (creator of the first verbot) in 1994 to describe these conversational programs.[5]
# ...

# %%
## creating a list of sentences
import nltk
nltk.download('popular',quiet=True)## for downloading packages
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
sent_tokenize = nltk.sent_tokenize(corpus)## converts to list of sentences
word_tokenize = nltk.word_tokenize(corpus) ## converts to list of words

# %%
## preprocessing for lemmatizer
def lemma(tokens):
    return [lemmatizer.lemmatize(token) for token in tokens]

# %%
## keyword matching
greeting_inputs = ('hello','hi','greetings')
greeting_responses = ('hi','hello','hi there')

def greeting(sentence):
    for word in sentence.spilit():
        if word.lower() in greeting_inputs:
            return random.choice(greeting_responses)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
def response(user_response):
    robo =''
    sent_tokenize.append(user_response)
    tv = Tfidfvectorizer()
    tfidf = tv.fit_transform(sent_tokenize)
    vals = cosine_similarity(tfidf[-1],tfidf)
    idx = sent_tokenize[vals.argsort()[0][-2]]
    flat = vals.flatten()
    flat.sort()
    if flat[-2]==0:
        return "please try again"
    else:
        idx

# %%
flag=True
print("robo: hello i am chatbot")
while(flag==True):
    user_response=input()
    user_response=user_response.lower()
    if (user_response!='bye'):
        if(user_response=='thanks'or user_response=='thank you'):
            flag=False
            print('robo: you are welcome')
        else:
            if(greeting(user_response)!=None):
                print("robo:"+greeting(user_response))
            else:
                print('robo:',end="")
# Out:
# robo: hello i am chatbot
# hi
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\CHIRAN~1\AppData\Local\Temp/ipykernel_7296/2434858925.py in <module>
#       9             print('robo: you are welcome')
#      10         else:
# ---> 11             if(greeting(user_response)!=None):
#      12                 print("robo:"+greeting(user_response))
#      13             else:
#
# C:\Users\CHIRAN~1\AppData\Local\Temp/ipykernel_7296/1046643240.py in greeting(sentence)
#       4
#       5 def greeting(sentence):
# ----> 6     for word in sentence.spilit():
#       7         if word.lower() in greeting_inputs:
#       8             return random.choice(greeting_responses)
#
# AttributeError: 'str' object has no attribute 'spilit'
